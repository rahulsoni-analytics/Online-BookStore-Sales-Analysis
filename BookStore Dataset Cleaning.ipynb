# %%
import pandas as pd

df = pd.read_excel(r"C:\Users\sonig\Downloads\E-commerce_Dataset.xlsx",sheet_name=None)

print(df.keys())
# Out:
# dict_keys(['customers', 'products', 'orders'])

# %%
# E- commerce Dataset Cleaning
# customers data cleaning process
# Out:
# dict_keys(['customers', 'products', 'orders'])

# %%
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   customer_id    5000 non-null   int64
#  1   customer_name  4851 non-null   object
#  2   email          4606 non-null   object
#  3   phone          5000 non-null   object
#  4   city           5000 non-null   object
#  5   country        4276 non-null   object
# dtypes: int64(1), object(5)
# memory usage: 234.5+ KB
# None

# %%
print(df["customers"].head(10))
# Out:
#    customer_id      customer_name                          email  \
# 0            1       Jacob Garcia               ryan56@yahoo.com
# 1            2      Robert Fuller               mark28@young.com
# 2            3   Crystal Hamilton             manuel36@gmail.com
# 3            4         Eric Welch         jennifer22@hotmail.com
# 4            5         Alexis Orr           parkmary@skinner.com
# 5            6    Erik Montgomery                            NaN
# 6            7      Douglas Perry  scottmiller@blevins-brady.net
# 7            8  Mr. Michael Allen               xirwin@yahoo.com
# 8            9       Katie Hunter      tanya89@miller-roman.info
# 9           10    Daniel Phillips             ahancock@gmail.com
#
#            phone            city country
# 0     3048482646     Grayborough  Canada
# 1     5147408332    Michaelburgh  Canada
# 2     5244341405        Taraberg      UK
# 3     5461663211     Austinburgh      UK
# 4     7031525435  Cassandrahaven     NaN
# ...

# %%
CT=df["customers"]

# %%
print(CT.head(15))
# Out:
#     customer_id      customer_name                          email  \
# 0             1       Jacob Garcia               ryan56@yahoo.com
# 1             2      Robert Fuller               mark28@young.com
# 2             3   Crystal Hamilton             manuel36@gmail.com
# 3             4         Eric Welch         jennifer22@hotmail.com
# 4             5         Alexis Orr           parkmary@skinner.com
# 5             6    Erik Montgomery                            NaN
# 6             7      Douglas Perry  scottmiller@blevins-brady.net
# 7             8  Mr. Michael Allen               xirwin@yahoo.com
# 8             9       Katie Hunter      tanya89@miller-roman.info
# 9            10    Daniel Phillips             ahancock@gmail.com
# 10           11   Alexander Cortez    michellestephens@baxter.com
# 11           12       Dawn Roberts     kari03@russell-sanders.com
# 12           13      Carlos Massey          langmichelle@cox.info
# ...

# %%
CT.isnull().sum()
# Out:
# customer_id        0
# customer_name    149
# email            394
# phone              0
# city               0
# country          724
# dtype: int64

# %%
CT.duplicated().sum()
# Out:
# np.int64(0)

# %%
CT[CT["phone"] == "invalid_phone"]
# Out:
#       customer_id      customer_name                      email  \
# 7               8  Mr. Michael Allen           xirwin@yahoo.com
# 12             13      Carlos Massey      langmichelle@cox.info
# 35             36   Nicholas Vincent   joyce76@novak-santos.com
# 42             43       Justin Gates      garciaamanda@wong.biz
# 54             55  Jennifer Anderson    christine22@hotmail.com
# ...           ...                ...                        ...
# 4936         4937       Matthew Tran     juarezlisa@hotmail.com
# 4948         4949      David Collier                        NaN
# 4976         4977        Grant Jones  stephenmorgan@hotmail.com
# 4981         4982    Selena Jennings        mmcmillan@lucas.com
# 4998         4999     Collin Sanchez      matthew04@hotmail.com
#
#               phone             city country
# 7     invalid_phone        Riggsstad     NaN
# 12    invalid_phone     Jonathanbury  india
# 35    invalid_phone       New Robert     NaN
# ...

# %%
CT["phone"] = CT["phone"].replace("invalid_phone",'')

# %%
CT[CT["phone"] == "invalid_phone"]
# Out:
# Empty DataFrame
# Columns: [customer_id, customer_name, email, phone, city, country]
# Index: []

# %%
CT["country"]=CT["country"].str.upper()

# %%
CT.head(10)
# Out:
#    customer_id      customer_name                          email       phone  \
# 0            1       Jacob Garcia               ryan56@yahoo.com  3048482646
# 1            2      Robert Fuller               mark28@young.com  5147408332
# 2            3   Crystal Hamilton             manuel36@gmail.com  5244341405
# 3            4         Eric Welch         jennifer22@hotmail.com  5461663211
# 4            5         Alexis Orr           parkmary@skinner.com  7031525435
# 5            6    Erik Montgomery                             NA  5276790793
# 6            7      Douglas Perry  scottmiller@blevins-brady.net  6433281205
# 7            8  Mr. Michael Allen               xirwin@yahoo.com
# 8            9       Katie Hunter      tanya89@miller-roman.info  9651816218
# 9           10    Daniel Phillips             ahancock@gmail.com  6714243645
#
#              city country
# 0     Grayborough  CANADA
# 1    Michaelburgh  CANADA
# 2        Taraberg      UK
# ...

# %%
CT[CT["country"].isnull()]
# Out:
# Empty DataFrame
# Columns: [customer_id, customer_name, email, phone, city, country]
# Index: []

# %%
CT["country"]=CT["country"].fillna("NA")

# %%
CT["email"]=CT["email"].fillna("NA")

# %%
CT[CT["email"].isnull()]
# Out:
# Empty DataFrame
# Columns: [customer_id, customer_name, email, phone, city, country]
# Index: []

# %%
CT["customer_name"]=CT["customer_name"].fillna("NA")

# %%
CT.isnull().sum()
# Out:
# customer_id      0
# customer_name    0
# email            0
# phone            0
# city             0
# country          0
# dtype: int64

# %%
CT.to_csv("new_customer.csv", index=False)

# %%
CT["city"]=CT["city"].replace(' ',"NA")

# %%
CT.to_csv("new_customer.csv", index=False)

# %%
CT.head(20)
# Out:
#     customer_id      customer_name                          email       phone  \
# 0             1       Jacob Garcia               ryan56@yahoo.com  3048482646
# 1             2      Robert Fuller               mark28@young.com  5147408332
# 2             3   Crystal Hamilton             manuel36@gmail.com  5244341405
# 3             4         Eric Welch         jennifer22@hotmail.com  5461663211
# 4             5         Alexis Orr           parkmary@skinner.com  7031525435
# 5             6    Erik Montgomery                             NA  5276790793
# 6             7      Douglas Perry  scottmiller@blevins-brady.net  6433281205
# 7             8  Mr. Michael Allen               xirwin@yahoo.com
# 8             9       Katie Hunter      tanya89@miller-roman.info  9651816218
# 9            10    Daniel Phillips             ahancock@gmail.com  6714243645
# 10           11   Alexander Cortez    michellestephens@baxter.com  5775592833
# ...

# %%
CT["city"]=CT["city"].replace(' ',"NA")

# %%
CT.to_csv("new_customers.csv", index=False)

# %%
# products data cleaning process

# %%
print(df["products"].head())
# Out:
#    product_id              book_title     genre    price  stock  \
# 0           1           Provide born.    SCI-FI  4938.16    142
# 1           2  Single collection use.       NaN  4278.52    251
# 2           3           Then popular.  fiction   3999.13    322
# 3           4        New real office.   History  3634.28    332
# 4           5    Western rather half.   Romance  2422.25    367
#
#    published_year
# 0          2018.0
# 1          2020.0
# 2          2023.0
# 3          2022.0
# 4          2020.0

# %%
PDT=df["products"]

# %%
PDT.isnull().sum()
# Out:
# product_id          0
# book_title          0
# genre             484
# price               0
# stock               0
# published_year    237
# dtype: int64

# %%
PDT.duplicated().sum()
# Out:
# np.int64(0)

# %%
PDT[PDT["genre"].isnull()]
# Out:
#       product_id                  book_title genre    price  stock  \
# 1              2      Single collection use.   NaN  4278.52    251
# 11            12     Property order it soon.   NaN   474.34    183
# 17            18          Purpose something.   NaN  1900.80    238
# 27            28        White along reflect.   NaN   333.61    112
# 31            32               Talk surface.   NaN    41.01    355
# ...          ...                         ...   ...      ...    ...
# 1989        1990                   Blue bad.   NaN  4941.98     -1
# 1990        1991   Arm century bad anything.   NaN  1991.25    246
# 1993        1994  Business generation above.   NaN   460.67    273
# 1994        1995                      Again.   NaN   460.14    231
# 1999        2000     Action speech campaign.   NaN   857.38    267
#
#       published_year
# 1             2020.0
# 11               NaN
# 17            2023.0
# 27            2020.0
# 31            2022.0
# ...              ...
# ...

# %%
PDT["genre"] = PDT["genre"].fillna("NA")

# %%
PDT[PDT["genre"].isnull()]
# Out:
# Empty DataFrame
# Columns: [product_id, book_title, genre, price, stock, published_year]
# Index: []

# %%
print(PDT.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2000 entries, 0 to 1999
# Data columns (total 6 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   product_id      2000 non-null   int64
#  1   book_title      2000 non-null   object
#  2   genre           2000 non-null   object
#  3   price           2000 non-null   float64
#  4   stock           2000 non-null   int64
#  5   published_year  1763 non-null   float64
# dtypes: float64(2), int64(2), object(2)
# memory usage: 93.9+ KB
# None

# %%
PDT["published_year"]=PDT["published_year"].fillna(PDT["published_year"].median())

# %%
PDT["genre"] = PDT["genre"].str.title()

# %%
PDT["genre"]=PDT["genre"].replace('Na',"NA")

# %%
print(PDT.head(20))
# Out:
#     product_id                      book_title     genre    price  stock  \
# 0            1                   Provide born.    Sci-Fi  4938.16    142
# 1            2          Single collection use.        NA  4278.52    251
# 2            3                   Then popular.  Fiction   3999.13    322
# 3            4                New real office.   History  3634.28    332
# 4            5            Western rather half.   Romance  2422.25    367
# 5            6           Politics institution.   History  2931.08    330
# 6            7                 Play while car.   Romance  4475.53    370
# 7            8               Without ago rate.    Sci-Fi  1650.78    425
# 8            9             First threat whole.  Fiction   3402.02     76
# 9           10             Media office front.   Romance  1732.16    144
# 10          11                      Any human.  Fiction    230.61    313
# 11          12         Property order it soon.        NA   474.34    183
# ...

# %%
PDT.to_csv("new_products.csv", index=False)

# %%
# orders data cleaning process

# %%
OD = df["orders"]

# %%
print(OD.head(20))
# Out:
#     order_id  customer_id  product_id  quantity order_date      status  \
# 0          1         3747         949        -1 2025-03-13          NA
# 1          2         1927        1565         3 2024-11-04     Pending
# 2          3          362        1331         3 2025-01-14  completed
# 3          4          825         361         7 2024-05-13   Completed
# 4          5         2023         470         1 2025-07-15   Cancelled
# 5          6         2927         642         6 2025-01-17          NA
# 6          7         3098        1547         9 2025-12-07   Cancelled
# 7          8         4278        1773        -1 2023-11-28  completed
# 8          9         3412         786        10 2024-10-07   Cancelled
# 9         10         1516         353        -1 2025-08-26     Pending
# 10        11         1213        2150         3 2024-12-26   Completed
# 11        12         2920        1910         0 2025-11-24   Completed
# ...

# %%
OD.isnull().sum()
# Out:
# order_id             0
# customer_id          0
# product_id           0
# quantity             0
# order_date           0
# status            3092
# payment_amount       0
# dtype: int64

# %%
OD.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15000 entries, 0 to 14999
# Data columns (total 7 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   order_id        15000 non-null  int64
#  1   customer_id     15000 non-null  int64
#  2   product_id      15000 non-null  int64
#  3   quantity        15000 non-null  int64
#  4   order_date      15000 non-null  datetime64[ns]
#  5   status          11908 non-null  object
#  6   payment_amount  15000 non-null  float64
# dtypes: datetime64[ns](1), float64(1), int64(4), object(1)
# memory usage: 820.4+ KB

# %%
OD.duplicated().sum()
# Out:
# np.int64(0)

# %%
OD["status"] = OD["status"].fillna("NA")

# %%
OD["status"] = OD["status"].str.strip().str.title()

# %%
print(OD.head(20))
# Out:
#     order_id  customer_id  product_id  quantity order_date     status  \
# 0          1         3747         949         4 2025-03-13         NA
# 1          2         1927        1565         3 2024-11-04    Pending
# 2          3          362        1331         3 2025-01-14  Completed
# 3          4          825         361         7 2024-05-13  Completed
# 4          5         2023         470         1 2025-07-15  Cancelled
# 5          6         2927         642         6 2025-01-17         NA
# 6          7         3098        1547         9 2025-12-07  Cancelled
# 7          8         4278        1773         4 2023-11-28  Completed
# 8          9         3412         786        10 2024-10-07  Cancelled
# 9         10         1516         353         4 2025-08-26    Pending
# 10        11         1213        2150         3 2024-12-26  Completed
# 11        12         2920        1910         0 2025-11-24  Completed
# ...

# %%
OD["status"] = OD["status"].replace("Na","NA")

# %%
OD["quantity"] = OD["quantity"].replace(-1,OD["quantity"].median())

# %%
CT.isnull().sum()
# Out:
# customer_id      0
# customer_name    0
# email            0
# phone            0
# city             0
# country          0
# dtype: int64

# %%
PDT.isnull().sum()
# Out:
# product_id        0
# book_title        0
# genre             0
# price             0
# stock             0
# published_year    0
# dtype: int64

# %%
OD.isnull().sum()
# Out:
# order_id          0
# customer_id       0
# product_id        0
# quantity          0
# order_date        0
# status            0
# payment_amount    0
# dtype: int64

# %%
OD.to_csv("new_orders.csv", index=False)
